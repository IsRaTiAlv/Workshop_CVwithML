# %% [markdown]
# ## Imports
# Comencemos importando las librerías. Aquí estamos importando TensorFlow y llamándolo tf para facilitar su uso. Luego importamos una biblioteca llamada numpy, que nos ayuda a representar nuestros datos como listas de manera fácil y rápida. El framework para definir una red neuronal como un conjunto de capas secuenciales se llama keras, por lo que también lo importamos.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# ## Define and Compile the Neural Network
# A continuación crearemos la red neuronal más simple posible. Tiene 1 capa, y esa capa tiene 1 neurona, y la forma de entrada es solo 1 valor.

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %% [markdown]
# Ahora compilamos nuestra red neuronal. Cuando lo hacemos, tenemos que especificar 2 funciones, una función de pérdida (loss) y un optimizador (optimizer).
#
# Sabemos que en nuestra función, la relación entre los números es y = 3x + 1.
#
# Cuando la computadora está tratando de "aprender" eso, hace una suposición, tal vez y = 10x + 10. La función PÉRDIDA mide las respuestas adivinadas contra las respuestas correctas conocidas y mide qué tan bien o qué tan mal lo hizo. Con el tiempo aprenderá las diferentes y apropiadas funciones de pérdida y optimizador para diferentes escenarios.
#
# Luego usa la función OPTIMIZER para minimizar la pérdida. En ese punto, tal vez aparezca algo como y = 5x + 5, que, aunque todavía es bastante malo, está más cerca del resultado correcto (es decir, la pérdida es menor). Se repetirá esto para la cantidad de EPOCHS que verá en breve.
#
# Pero primero, así es como le decimos que use 'mean_squared_error' para la pérdida y 'sdg' para el optimizador.

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# ## Providing the Data
#
# A continuación introduciremos algunos datos. En este caso estamos tomando 6 pares de datos (x,y). Puede ver que la relación entre estos es que y = 2x-1, entonces donde x = -1, y = -3 etc. etc.
#
# Una biblioteca de Python llamada 'Numpy' proporciona muchas estructuras de datos de tipo de matriz que son una forma estándar de hecho de hacerlo. Declaramos que queremos usarlos especificando los valores como np.array []

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

# %% [markdown]
# # Training the Neural Network

# %% [markdown]
# El proceso de entrenamiento de la red neuronal, donde 'aprende' la relación entre las X y las Y está en la llamada ** model.fit **. Aquí es donde pasará por el ciclo del que hablamos anteriormente, haciendo una suposición, midiendo qué tan bueno o malo es (también conocido como la pérdida), usando el opimizador para hacer otra suposición, etc. Lo hará por la cantidad de épocas que especificar. Cuando ejecute este código, verá la pérdida en el lado derecho.

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 1ms/step - loss: 102.4324 - accuracy: 0.0000e+00
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 80.5992 - accuracy: 0.0000e+00
# Epoch 3/500
# 1/1 [==============================] - 0s 1ms/step - loss: 63.4216 - accuracy: 0.0000e+00
# Epoch 4/500
# 1/1 [==============================] - 0s 3ms/step - loss: 49.9070 - accuracy: 0.0000e+00
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 39.2741 - accuracy: 0.0000e+00
# Epoch 6/500
# 1/1 [==============================] - 0s 2ms/step - loss: 30.9085 - accuracy: 0.1667
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 24.3266 - accuracy: 0.1667
# Epoch 8/500
# 1/1 [==============================] - 0s 1ms/step - loss: 19.1481 - accuracy: 0.1667
# Epoch 9/500
# 1/1 [==============================] - 0s 1ms/step - loss: 15.0738 - accuracy: 0.1667
# Epoch 10/500
# ...

# %% [markdown]
# De acuerdo, ahora tiene un modelo que ha sido entrenado para aprender la relación entre X e Y. Puede usar el método **model.predict ** para que descubra la Y para una X previamente desconocida. Entonces, por ejemplo, si X = 10, ¿qué crees que será Y?

# %%
print(model.predict([10.0]))
# Out:
# [[31.006144]]

# %% [markdown]
# Podrías haber pensado 31, ¿verdad? Pero terminó siendo un poco más. ¿Por qué crees que es?
#
# Recuerde que las redes neuronales se ocupan de las probabilidades, por lo tanto, dados los datos con los que alimentamos el NN, este calculó que existe una probabilidad muy alta de que la relación entre X e Y sea Y = 3X + 1, pero con solo 6 puntos de datos esto no es muy seguro. Como resultado, la predicción para 10 está muy cerca de 31, pero no necesariamente 31. A medida que trabaje con redes neuronales, verá este patrón recurrente. Casi siempre lidiará con las probabilidades, no con las certezas, y hará un poco de codificación para descubrir cuál es el resultado en función de las probabilidades, particularmente cuando se trata de la clasificación.
